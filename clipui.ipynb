# %%
# !pip install torch torchvision torchaudio scikit-image colormath opencv-python tqdm lmdb tensorboardX wandb scikit-image opencv-python fvcore ftfy regex tqdm json5 ftfy regex tqdm
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.4/299.4 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.2 MB/s eta 0:00:00
# ...
#   Created wheel for colormath: filename=colormath-3.0.0-py3-none-any.whl size=39405 sha256=d69f0141ae96a8e9df627b6161e3eccecc6591ef652f18611d70cb74be4f11d5
#   Stored in directory: /root/.cache/pip/wheels/9a/32/6a/605739a172d8112031c9875d744aef91709f00de9b3bbb9274
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=cc2895c811eff649269a92c939cbe4913b71e581af68e2ddf2e3d97a2080bcee
# ...

# %%
# !pip install -q git+https://github.com/openai/CLIP.git

print("clip installed!")
# Out:
#   Preparing metadata (setup.py) ... done
# ...
# clip installed!

# %%
# Install PyTorch 2.4.0 + cu121 build
# !pip install torch==2.4.0+cu121 torchvision==0.19.0+cu121 torchaudio==2.4.0+cu121 \
  --index-url https://download.pytorch.org/whl/cu121

# Install dependencies for Mamba
# !pip install causal-conv1d==1.4.0
# !pip install mamba-ssm==2.2.2
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.0/799.0 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 113.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 89.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 105.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 47.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 134.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 22.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.1 MB/s eta 0:00:00
# ...

# %%
import torch
import mamba_ssm

# Check versions
print(f"✅ PyTorch: {torch.__version__}")
print(f"✅ Mamba: {mamba_ssm.__version__}")
print(f"✅ CUDA Available: {torch.cuda.is_available()}")

# Quick Mamba Test
from mamba_ssm import Mamba
model = Mamba(d_model=64, d_state=16, d_conv=4, expand=2).cuda()
x = torch.randn(1, 10, 64).cuda()
y = model(x)
print(f"🎉 Mamba Model Test Output: {y.shape}")
# Out:
# /usr/local/lib/python3.12/dist-packages/mamba_ssm/ops/selective_scan_interface.py:163: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /usr/local/lib/python3.12/dist-packages/mamba_ssm/ops/selective_scan_interface.py:239: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /usr/local/lib/python3.12/dist-packages/mamba_ssm/ops/triton/layer_norm.py:985: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /usr/local/lib/python3.12/dist-packages/mamba_ssm/ops/triton/layer_norm.py:1044: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# ...

# %%
# @title RUN TRAINING — CLIP-UIE + UIEB + NOVELTY
# %cd /content/drive/MyDrive/CLIP-UIE
# !python train.py -c config/pretrain_uieb.json
# Out:
# /content/drive/.shortcut-targets-by-id/1JvpyhsCKpMJKgzxk6Wh93-xJEbpwsrgz/CLIP-UIE
# 2025-11-19 19:17:56,616 - INFO: Log file: /content/drive/MyDrive/CLIP-UIE/logs/train_20251119_191756.log
# 2025-11-19 19:17:56,673 - INFO: Dataset [LRHRDataset - UIEB_train] is created.
# 2025-11-19 19:17:56,691 - INFO: Dataset [LRHRDataset - UIEB_val] is created.
# 2025-11-19 19:17:56,692 - INFO: Train: 890 images | Val: 10 images
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 2025-11-19 19:18:13,874 - INFO: 🚀 Using Enhanced U-Net (SOTA 2024-2025)
# 2025-11-19 19:18:13,922 - INFO: ✓ Architecture: Axial DWConv + SimAM + SK Fusion
# The initial prompts are: /content/drive/MyDrive/CLIP-UIE/Checkpoint/prompt/iter_1000.pth
# ...

# %%
# %cd /content/drive/MyDrive/CLIP-UIE

# !python train.py -c config/mamba_uieb.json
# Out:
# /content/drive/.shortcut-targets-by-id/1JvpyhsCKpMJKgzxk6Wh93-xJEbpwsrgz/CLIP-UIE
# 2025-11-21 13:29:24,010 - INFO: Log file: /content/drive/MyDrive/CLIP-UIE/logs/train_20251121_132924.log
# 2025-11-21 13:29:28,413 - INFO: Dataset [LRHRDataset - UIEB_train] is created.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 2025-11-21 13:29:28,430 - INFO: Dataset [LRHRDataset - UIEB_val] is created.
# 2025-11-21 13:29:28,431 - INFO: Train: 890 images | Val: 10 images
# 2025-11-21 13:29:29,759 - INFO: 🐍 MAMBA U-NET ACTIVATED!
# ...

# %%
# %cd /content/drive/MyDrive/CLIP-UIE

# !python train.py -c config/mamba_uieb.json
# Out:
# /content/drive/.shortcut-targets-by-id/1JvpyhsCKpMJKgzxk6Wh93-xJEbpwsrgz/CLIP-UIE
# 2025-11-22 13:25:43,910 - INFO: Log file: /content/drive/MyDrive/CLIP-UIE/logs/train_20251122_132543.log
# 2025-11-22 13:25:47,806 - INFO: Dataset [LRHRDataset - UIEB_train] is created.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 2025-11-22 13:25:47,831 - INFO: Dataset [LRHRDataset - UIEB_val] is created.
# 2025-11-22 13:25:47,832 - INFO: Train: 890 images | Val: 10 images
# ...

# %%
# %cd /content/drive/MyDrive/CLIP-UIE

# !python train.py -c config/mamba_uieb.json
# Out:
# /content/drive/.shortcut-targets-by-id/1JvpyhsCKpMJKgzxk6Wh93-xJEbpwsrgz/CLIP-UIE
# 2025-11-26 16:21:12,657 - INFO: Log file: /content/drive/MyDrive/CLIP-UIE/logs/train_20251126_162112.log
# 2025-11-26 16:21:15,867 - INFO: Dataset [LRHRDataset - UIEB_train] is created.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 2025-11-26 16:21:15,885 - INFO: Dataset [LRHRDataset - UIEB_val] is created.
# 2025-11-26 16:21:15,885 - INFO: Train: 890 images | Val: 10 images
# ...
